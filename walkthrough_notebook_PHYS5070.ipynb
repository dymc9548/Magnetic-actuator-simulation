# %% [markdown]
# # Initial visualization of hinging magnetic microrobots

# %% [markdown]
# ### This notebook is to set up the initial visualization of the hinge-connected magnetic microrobots.

# %% [markdown]
# ### Introduction

# %% [markdown]
# For this project, we attempt to simulate the folding of hinge-connected magnetic microrobots. Our experimental system consists of particles printed by two-photon lithography comprising cubes connected by hinges, where changing the orientation of the hinges allows for three-dimensional folding built from rotations about each hinge's degree of freedom. We apply ferromagnetic patches to our particles, such that the dipole-dipole interactions between the residual dipole moments in the patches cause conformational changes of the particles.
#
# These particles could be used for biomedical purposes in areas such as drug delivery. However, such applications often require specific folded states. Our microrobots are fabricated using top-down methods, which makes prediction of final folding from initial structure difficult. The goal of this simulation is to predict final conformation probabilities from initial structure to allow for better characterization and application-based fabrication.
#
# In this Jupyter notebook, we walk through the code necessary to simulate this folding process. We examine folding in two dimensions for initial simplicity. We implement two methods of simulation: greedy descent and Monte Carlo. Both methods involve energy minimization, where the energy between two patches is calculated with the following formula:
#
# \begin{equation}
# E = \frac{\mu_0}{4\pi}\left(\frac{|\vec{m}|}{2 l}\right)^2\left[\frac{1}{|\vec{r_{13}}|} - \frac{1}{|\vec{r_{14}}|} - \frac{1}{|\vec{r_{23}}|} + \frac{1}{|\vec{r_{24}}|}\right].
# \end{equation}
#
# The total energy is calculated by summing over the patch-patch energies for all patch pairs. Note that we are approximating each patch as a dipole.
#
# For greedy descent, we go through each hinge, rotate by a random angle, and store the energy change. Then, we only accept the single hinge movement that yielded the lowest energy. Repeating this until steric hindrance renders favorable moves impossible yields a state in an energy minimum.
#
# For Monte Carlo, we implement the standard Metropolis acceptance procedure. We pick a random hinge and a random angle. Then, all negative-energy moves are accepted, and each positive-energy move is accepted with a probability proportional to the Boltzmann factor for that energy. This allows for the overcoming of energy barriers.
#
# We perform clustering by final state hinge angles in N-dimensional space, where N is the number of hinges. Comparing the clusters across methods reveals that our process is relatively deterministic.
#
# The remainder of this notebook will walk through our process for simulating this folding.

# %% [markdown]
# ### Imports

# %%
import numpy as np  # Numerical operations and array manipulations
import matplotlib.pyplot as plt  # Plotting and data visualization
import pandas as pd  # Data structures for handling data (e.g., DataFrame)
import visualization_functions as vis # our functions for visualization
import sim_methods as sim # our functions for simulation

# %% [markdown]
# ### Generating a sequence

# %% [markdown]
# First, we set up the shape dictionary, which will keep track of all parameters associated with each unit (currently cubes/squares) in the particle.

# %%
# The setup is as follows:
# shapes = {'shape 1': ['s', shapeLength, spacingFromPrevious, spacingVariability, patch_dict = {'patch 1':[location, length, edgeOffset], 'patch 2': [location2, length2, offset2]}]}

shapes = {'shape 1': ['s', 10, 0, 0, {'patch 1': ['top right', 4, 0]}], 'shape 2':['s', 10, 6, 0, {'patch 1': ['top left', 4, 0], 'patch 2': ['bottom right', 4, 0]}], 'shape 3': ['s', 10, 6, 0, {'patch 1': ['bottom left', 4, 0],'patch 2': ['bottom right', 4, 0]}], 
          'shape 4': ['s', 10, 6, 0, {'patch 1': ['bottom left', 4, 0]}]}

# %% [markdown]
# Now, we need to generate the sequence, which gives us informational arrays about the structure of shapes, hinges, etc.

# %%
hinge_vec, hinge_loc, shape_arr, linelist, patch_arr, patch_num = vis.generate(shapes)

# %% [markdown]
# Finally, we need to plot the sequence

# %%
vis.shapeplots(shape_arr, linelist, hinge_loc, blocking = False, title = 'Initial Sequence Conformation', show = True, bounds = '', mag_vecs = patch_arr)

# %% [markdown]
# Count the number of shapes. This function is essential for determining if the sequence overlaps itself during folding. If a different number of polygons is counted at any point that is different from the number calculated here, we know that there is overlap in the sequence

# %%
polycount = vis.count_shapes(shape_arr)
print(polycount)
# Out:
# 4

# %%
overlap = vis.check_overlap(shape_arr, polycount)
print(overlap)
# Out:
# False

# %% [markdown]
# ### Moving a hinge

# %% [markdown]
# This next code is not necessary to run full simulations, but is included here for demonstration purposes, showing how the sequence moves. The general algorithm is: translate hinge to origin, rotate everything to the right of hinge using multiplication by the rotation matrix, translate the hinge back to its position before the move. As an example here, hinge 0 will be manipulated

# %% [markdown]
# Move hinge to origin:

# %%
hingechoice = 0 # choose the hinge to rotate
patch_arr_new, shape_arr_new,hinge_loc_new  = vis.translate_to_origin(patch_arr, shape_arr, hinge_loc, hingechoice) # move hinge to origin
vis.shapeplots(shape_arr_new, linelist, hinge_loc_new, mag_vecs = patch_arr_new)

# %% [markdown]
# Rotate by set angle:

# %%
angle = 30
patch_arr_new, shape_arr_new, hinge_vec_new, hinge_loc_new = vis.rotate(patch_arr_new, shape_arr_new, linelist, hinge_vec, hinge_loc_new, hingechoice, angle, patch_num)
vis.shapeplots(shape_arr_new, linelist, hinge_loc_new, mag_vecs = patch_arr_new)

# %% [markdown]
# Translate back to original location:

# %%
patch_arr_new,shape_arr_new,hinge_loc_new = vis.translate_back(patch_arr_new,shape_arr_new,hinge_loc_new)
vis.shapeplots(shape_arr_new, linelist, hinge_loc_new, mag_vecs = patch_arr_new)

# %% [markdown]
# ##### This whole operation can be done altogether using the function below:

# %%
hingechoice = 0
angle = 30
patch_arr_new, shape_arr_new, hinge_vec_new, hinge_loc_new = vis.rotate_once(patch_arr,shape_arr,linelist,hinge_vec,hingechoice, hinge_loc, angle, patch_num)
vis.shapeplots(shape_arr_new, linelist, hinge_loc_new, mag_vecs = patch_arr_new)

# %% [markdown]
# ### Magnetics and energies

# %% [markdown]
# Define the magnetization (from experiments) and setup a magnetization vector

# %%
# Define the magnetization/length of each patch. This is defined from experimental measured values as mentioned in the manuscript
m = np.array([1.01e-6]*sum(patch_num)) # Can change the values of the moments here if we do patches of different sizes

# Establish the magnetic vector containing all of the magnetizations/shape of each magnetic domain (ends of the patches), necessary for energy calculation
magvec = np.repeat(m, 2) # the endpoints are the domains we care about, so this is just a 2n-dim array of the same values as m, where n is the dim of m

# %% [markdown]
# Initialize arrays used in the energy calculation of each sequence.

# %%
mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat = vis.initialize_energy(magvec)

# %% [markdown]
# Test calculate the energy in Joules

# %%
E = vis.energy_math(patch_arr,mask_arr, v_xmat, h_xmat, v_ymat, h_ymat,Ml_mat)
print(E)
# Out:
# -4.151777868204307e-14

# %% [markdown]
# This calculation has been confirmed by hand!

# %% [markdown]
# Test calculate the energy in Joules of the rotated hinge

# %%
E2 = vis.energy_math(patch_arr_new,mask_arr, v_xmat, h_xmat, v_ymat, h_ymat,Ml_mat)
print(E2)
# Out:
# -5.042511444758076e-14

# %% [markdown]
# This calculation has been confirmed by hand!

# %%
# Print the difference to compare energy change to kT (roughly 10^-21)
print(E2-E)
# Out:
# -8.907335765537687e-15

# %% [markdown]
# I created a cutoff energy minimum in case the patches ever touch to avoid a singularity at r=0. The code below is testing that the cutoff works and the energy is continuous:

# %%
angles = np.linspace(0,70,100)
hingechoice = 0
E = []
for angle in angles:
    patch_arr_new, shape_arr_new, hinge_vec_new, hinge_loc_new = vis.rotate_once(patch_arr,shape_arr,linelist,hinge_vec,hingechoice, hinge_loc, angle, patch_num)
    E.append(vis.energy_math(patch_arr_new,mask_arr, v_xmat, h_xmat, v_ymat, h_ymat,Ml_mat))

plt.plot(angles,E)
plt.xlabel("angle")
plt.ylabel("E")
# plt.xlim(61.925,61.94)
# plt.ylim(-1.5e-9,-1.4e-9)
# Out:
# Text(0, 0.5, 'E')

# %% [markdown]
# ### Simulation (greedy descent)

# %% [markdown]
# Starting with our three-hinge conformation above, we perform greedy descent to arrive at a final conformation

# %%
std = 10 # angle distribution std
max_iter = 1000 # maximum moves
patch_arr_sim, shape_arr_sim, hinge_vec_sim, hinge_loc_sim, current_energy_sim = sim.simulate_greedyDescent(patch_arr,shape_arr,linelist,hinge_vec, hinge_loc, std, patch_num, mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat, max_iter, tol=0)
# Out:
# Current energy:  -1.2758095987584695e-11  Joules

# %%
vis.shapeplots(shape_arr_sim, linelist,hinge_loc_sim, mag_vecs = patch_arr_sim) # plot the resulting final state
print("Energy is: ", vis.energy_math(patch_arr_sim,mask_arr, v_xmat, h_xmat, v_ymat, h_ymat,Ml_mat))
# Out:
# Energy is:  -1.2758095987584695e-11

# %% [markdown]
# We can now simulate many times for clustering

# %%
# sim many times
std = 10 # angle distribution std
max_iter = 1000 # maximum moves
nsim = 100 # number of simulations
final_hinges, final_es = sim.sim_many(nsim, 'greedy descent',patch_arr,shape_arr,linelist,hinge_vec, hinge_loc, std, patch_num, mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat, max_iter, tol=0, plot=False)
# Out:
# Current energy:  -2.5964036027454025e-11  Joules
# Current energy:  -5.048169261801306e-12  Joules
# Current energy:  -1.1356803610497638e-11  Joules
# Current energy:  -8.525394773693158e-12  Joules
# Current energy:  -6.672248443646618e-11  Joules
# Current energy:  -2.2606662060132808e-11  Joules
# Current energy:  -7.321277785952643e-11  Joules
# Current energy:  -1.3112287019034718e-11  Joules
# Current energy:  -4.0591606861219814e-11  Joules
# Current energy:  -6.881373837359914e-12  Joules
# Current energy:  -8.930587938817743e-12  Joules
# Current energy:  -5.042242555869042e-11  Joules
# Current energy:  -7.266860736064784e-11  Joules
# Current energy:  -2.8834773219890448e-11  Joules
# Current energy:  -2.116356072748868e-11  Joules
# Current energy:  -3.264339337582579e-11  Joules
# Current energy:  -1.574325144299848e-10  Joules
# Current energy:  -1.9549286450374974e-11  Joules
# Current energy:  -7.750693353339104e-12  Joules
# Current energy:  -1.2095505759804571e-11  Joules
# Current energy:  -1.2720776006221693e-11  Joules
# Current energy:  -9.853408443692018e-12  Joules
# Current energy:  -8.68866924050462e-12  Joules
# Current energy:  -6.800097129795782e-12  Joules
# Current energy:  -2.5638907046243798e-11  Joules
# Current energy:  -4.9254133564234855e-11  Joules
# Current energy:  -2.1875596695993154e-11  Joules
# Current energy:  -4.817378979417521e-12  Joules
# Current energy:  -8.300773420160239e-11  Joules
# Current energy:  -1.0446585604955421e-11  Joules
# Current energy:  -4.0367927956332125e-11  Joules
# Current energy:  -1.6345438139168395e-11  Joules
# Current energy:  -2.2819940386179608e-11  Joules
# Current energy:  -2.1004458061706772e-11  Joules
# Current energy:  -5.151631434503068e-12  Joules
# Current energy:  -8.062542917928292e-12  Joules
# Current energy:  -1.5000712122385553e-11  Joules
# Current energy:  -2.7690669886383033e-11  Joules
# Current energy:  -1.0355322584622425e-11  Joules
# Current energy:  -1.2251366392274724e-11  Joules
# Current energy:  -1.2332735991200463e-10  Joules
# Current energy:  -1.9675966958170257e-11  Joules
# Current energy:  -6.017761704152596e-12  Joules
# Current energy:  -2.333341717293321e-11  Joules
# Current energy:  -4.056163589864328e-12  Joules
# Current energy:  -4.789052873218264e-12  Joules
# Current energy:  -1.907443155929752e-10  Joules
# Current energy:  -8.776462682757382e-12  Joules
# Current energy:  -3.294690646896443e-11  Joules
# Current energy:  -2.3764501068297836e-11  Joules
# Current energy:  -1.533211037148862e-11  Joules
# Current energy:  -1.2000884992854792e-09  Joules
# Current energy:  -1.021600659619982e-10  Joules
# Current energy:  -6.7774019591663205e-12  Joules
# Current energy:  -2.4502433224530242e-12  Joules
# Current energy:  -2.3525052768865515e-11  Joules
# Current energy:  -3.309059108053621e-11  Joules
# Current energy:  -4.58288511961349e-12  Joules
# Current energy:  -9.603077450276975e-12  Joules
# Current energy:  -1.1613496251536218e-11  Joules
# Current energy:  -6.706659705084026e-12  Joules
# Current energy:  -1.831498566983722e-11  Joules
# Current energy:  -6.5993400521464865e-12  Joules
# Current energy:  -6.460502014153392e-12  Joules
# Current energy:  -1.4685470957261794e-11  Joules
# Current energy:  -9.991316504765482e-10  Joules
# Current energy:  -3.623874535720654e-12  Joules
# Current energy:  -1.791329407657972e-11  Joules
# Current energy:  -3.3289517615935773e-12  Joules
# Current energy:  -2.0455762561702726e-11  Joules
# Current energy:  -1.6140766978103348e-10  Joules
# Current energy:  -3.6090787820416826e-12  Joules
# Current energy:  -1.1767875328577297e-11  Joules
# Current energy:  -2.067537969775552e-11  Joules
# Current energy:  -9.034103676020905e-12  Joules
# Current energy:  -1.2773154758682279e-11  Joules
# Current energy:  -6.608307348105362e-12  Joules
# Current energy:  -1.4534306421942919e-11  Joules
# Current energy:  -5.86183842671257e-12  Joules
# Current energy:  -4.068049451498166e-12  Joules
# Current energy:  -1.6496914321857792e-11  Joules
# Current energy:  -5.621384301987547e-11  Joules
# Current energy:  -6.43909918903296e-11  Joules
# Current energy:  -4.315871923506213e-11  Joules
# Current energy:  -3.0351186112283716e-11  Joules
# Current energy:  -1.0769793179727923e-11  Joules
# Current energy:  -3.909478272700558e-12  Joules
# Current energy:  -2.078802334818715e-11  Joules
# Current energy:  -7.239541925119685e-11  Joules
# Current energy:  -1.1067769440864193e-11  Joules
# Current energy:  -8.941935470440269e-12  Joules
# Current energy:  -4.073060430054608e-11  Joules
# Current energy:  -4.244271329577144e-11  Joules
# Current energy:  -1.0302678984951337e-11  Joules
# Current energy:  -4.821973966649046e-11  Joules
# Current energy:  -4.378332533171014e-12  Joules
# Current energy:  -1.599016717826706e-11  Joules
# Current energy:  -1.1799288679612637e-11  Joules
# Current energy:  -1.125704612780763e-11  Joules
# Current energy:  -2.0348183463795905e-11  Joules

# %% [markdown]
# Clustering: we plot two different methods (Silhouette and Davies-Bouldin scores) to determine optimal cluster count. A higher value of the Silhouette score is better, while a lower value of the Davies-Bouldin score is better. We take the maximum optimal cluster number yielded by the two scores.

# %%
cluster_max = 5
states = 10 #A cluster parameter that allows the KMeans clustering to try out different initial states for better optimization
clusternumber = vis.cluster_num(final_hinges,cluster_max,states, Plot = True)

# %% [markdown]
# We can plot the clusters for our three-hinge system in 3D space:

# %%
clustercenters, cluster_labels, clusternumber = vis.min_cluster_centers(final_hinges, clusternumber, final_es, Plots = '3D')

# %% [markdown]
# Note that the variations in angles are minimal, so we are likely creating clusters from very little differences in the data. We can group the clusters by their energy minima to see the frequency of each cluster:

# %%
clusternumbers, cluster_count, cluster_prob, energies, ordered_centers, all_stds = vis.cluster_stats(final_hinges, clusternumber, clustercenters, cluster_labels,
                                                                                                    final_es, plot=True)

# %% [markdown]
# So, we see that the one energy state is the more likely outcome here, which makes sense. In reality, we're forcing clusters from very little differences in the data. So, let's now examine a more complex system.

# %% [markdown]
# ### More complex clustering

# %% [markdown]
# We now examine a more complicated shape array that could have multiple final conformations

# %%
# more complicated shape array
shapes = {'shape 1': ['s', 10, 0, 0, {'patch 1': ['top right', 4, 0]}], 'shape 2':['s', 10, 6, 0, {'patch 1': ['top left', 4, 0], 'patch 2': ['bottom right', 4, 0]}], 'shape 3': ['s', 10, 6, 0, {'patch 1': ['bottom left', 4, 0]}], 
          'shape 4': ['s', 10, 6, 0, {'patch 1': ['bottom left', 4, 0]}], 'shape 5': ['s', 10, 6, 0, {'patch 1': ['top left', 4, 0]}], 'shape 6': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 7': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 8': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 9': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 10': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 11': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}]}
hinge_vec, hinge_loc, shape_arr, linelist, patch_arr, patch_num = vis.generate(shapes)
vis.shapeplots(shape_arr, linelist, hinge_loc, blocking = False, title = 'Initial Sequence Conformation', show = True, bounds = '', mag_vecs = patch_arr)

# %%
# Define the magnetization/length of each patch. This is defined from experimental measured values as mentioned in the manuscript
m = np.array([1.01e-6]*sum(patch_num)) # Can change the values of the moments here if we do patches of different sizes

# Establish the magnetic vector containing all of the magnetizations/shape of each magnetic domain (ends of the patches), necessary for energy calculation
magvec = np.repeat(m, 2) # the endpoints are the domains we care about, so this is just a 2n-dim array of the same values as m, where n is the dim of m

mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat = vis.initialize_energy(magvec)

# %%
std = 10 # angle distribution std
max_iter = 1000 # maximum moves
patch_arr_sim, shape_arr_sim, hinge_vec_sim, hinge_loc_sim, current_energy_sim = sim.simulate_greedyDescent(patch_arr,shape_arr,linelist,hinge_vec, hinge_loc, std, patch_num, mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat, max_iter, tol=0)
vis.shapeplots(shape_arr_sim, linelist,hinge_loc_sim, mag_vecs = patch_arr_sim)
# Out:
# Current energy:  -2.1306102659659768e-10  Joules

# %%
# sim many times
std = 10 # angle distribution std
max_iter = 1000 # maximum moves
nsim = 100 # number of simulations
final_hinges, final_es = sim.sim_many(nsim, 'greedy descent',patch_arr,shape_arr,linelist,hinge_vec, hinge_loc, std, patch_num, mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat, max_iter, tol=0, plot=False)
# Out:
# Current energy:  -2.0134150690477873e-11  Joules
# Current energy:  -1.0969190174410743e-11  Joules
# Current energy:  -1.7689692332324946e-10  Joules
# Current energy:  -2.8635371463664703e-11  Joules
# Current energy:  -1.065484482590768e-10  Joules
# Current energy:  -7.904378639342626e-11  Joules
# Current energy:  -1.72999470595755e-11  Joules
# Current energy:  -4.238887345249566e-11  Joules
# Current energy:  -3.790492131336714e-11  Joules
# Current energy:  -6.06185910117146e-11  Joules
# Current energy:  -6.441257666806698e-11  Joules
# Current energy:  -1.0678993567240941e-09  Joules
# Current energy:  -9.245298264003806e-12  Joules
# Current energy:  -5.977925367857195e-10  Joules
# Current energy:  -6.216931142004151e-11  Joules
# Current energy:  -8.526349900724996e-11  Joules
# Current energy:  -5.170021290361873e-11  Joules
# Current energy:  -1.9212592444429268e-11  Joules
# Current energy:  -8.828300594245407e-11  Joules
# Current energy:  -1.0635078019046118e-10  Joules
# Current energy:  -1.4843675139564297e-11  Joules
# Current energy:  -5.7892374288383415e-11  Joules
# Current energy:  -1.2390032426405581e-10  Joules
# Current energy:  -1.3481302657257825e-10  Joules
# Current energy:  -3.5402023642637825e-10  Joules
# Current energy:  -1.4730719709914433e-10  Joules
# Current energy:  -3.3111604993790766e-10  Joules
# Current energy:  -6.243944625668611e-11  Joules
# Current energy:  -3.244529188555242e-11  Joules
# Current energy:  -6.29139083785941e-10  Joules
# Current energy:  -2.6841028888988608e-11  Joules
# Current energy:  -8.25684499567818e-10  Joules
# Current energy:  -9.40496505356185e-11  Joules
# Current energy:  -6.125287679151446e-11  Joules
# Current energy:  -5.14811485784799e-11  Joules
# Current energy:  -1.6610085415263828e-10  Joules
# Current energy:  -4.5835150296897674e-11  Joules
# Current energy:  -3.5402271178678426e-11  Joules
# Current energy:  -1.4950742432202054e-11  Joules
# Current energy:  -2.2933765270845933e-11  Joules
# Current energy:  -1.6033917431989654e-11  Joules
# Current energy:  -2.9584785750556196e-11  Joules
# Current energy:  -6.657930821974648e-11  Joules
# Current energy:  -2.8845620190472228e-11  Joules
# Current energy:  -1.2915017962431312e-11  Joules
# Current energy:  -3.168494695536023e-11  Joules
# Current energy:  -3.354171025484354e-11  Joules
# Current energy:  -1.7597305956442942e-11  Joules
# Current energy:  -7.543797632838544e-11  Joules
# Current energy:  -2.3960462947732047e-10  Joules
# Current energy:  -5.287450017872909e-11  Joules
# Current energy:  -1.0228713702503414e-11  Joules
# Current energy:  -1.480364184609709e-11  Joules
# Current energy:  -7.834068900002085e-11  Joules
# Current energy:  -6.009374291089514e-11  Joules
# Current energy:  -4.162182524470998e-11  Joules
# Current energy:  -2.2708128291471318e-10  Joules
# Current energy:  -3.244546225186235e-11  Joules
# Current energy:  -1.0509311249587312e-11  Joules
# Current energy:  -8.584999213168602e-11  Joules
# Current energy:  -4.760787158881027e-10  Joules
# Current energy:  -7.434514096752206e-11  Joules
# Current energy:  -2.4641842683534542e-11  Joules
# Current energy:  -1.3517031086449312e-10  Joules
# Current energy:  -5.001171268846173e-11  Joules
# Current energy:  -8.07966936274987e-11  Joules
# Current energy:  -1.44029049981736e-10  Joules
# Current energy:  -2.915754088139318e-09  Joules
# Current energy:  -2.532663880191461e-11  Joules
# Current energy:  -6.561207089610414e-11  Joules
# Current energy:  -2.2201159472019054e-11  Joules
# Current energy:  -1.2778955288997822e-11  Joules
# Current energy:  -2.8887627923491478e-11  Joules
# Current energy:  -1.2313940631763303e-11  Joules
# Current energy:  -2.2808532889227024e-10  Joules
# Current energy:  -4.677343571820801e-11  Joules
# Current energy:  -1.0933551079315858e-10  Joules
# Current energy:  -2.160655788939165e-11  Joules
# Current energy:  -5.507026028795335e-11  Joules
# Current energy:  -1.4526427905160468e-11  Joules
# Current energy:  -9.707955128053855e-11  Joules
# Current energy:  -5.222935954320414e-10  Joules
# Current energy:  -2.0572848804392557e-10  Joules
# Current energy:  -1.9181271040307234e-11  Joules
# Current energy:  -3.7611134482293694e-11  Joules
# Current energy:  -1.686411037470137e-10  Joules
# Current energy:  -5.625063284302869e-11  Joules
# Current energy:  -8.631514349717512e-11  Joules
# Current energy:  -3.210837273133042e-11  Joules
# Current energy:  -5.623465789692812e-11  Joules
# Current energy:  -1.4331332635161128e-10  Joules
# Current energy:  -8.079220177965227e-11  Joules
# Current energy:  -1.1518170737812812e-10  Joules
# Current energy:  -1.311885128830263e-11  Joules
# Current energy:  -1.6425535334470545e-10  Joules
# Current energy:  -1.0549672369669893e-10  Joules
# Current energy:  -2.5475915055114956e-11  Joules
# Current energy:  -1.217505382808775e-10  Joules
# Current energy:  -2.3200553170750996e-10  Joules
# Current energy:  -5.45886434190986e-11  Joules

# %%
cluster_max = 9
states = 10 #A cluster parameter that allows the KMeans clustering to try out different initial states for better optimization
clusternumber = vis.cluster_num(final_hinges,cluster_max,states, Plot = True)

# %%
clustercenters, cluster_labels, clusternumber = vis.min_cluster_centers(final_hinges, clusternumber, final_es)

# %%
clusternumbers, cluster_count, cluster_prob, energies, ordered_centers, all_stds = vis.cluster_stats(final_hinges, clusternumber, clustercenters, cluster_labels,
                                                                                                    final_es, plot=True)

# %% [markdown]
# We see that the most common outcome is by far the lowest energy state. We can compare this energy to the calculated energies for example states to find the conformation that corresponds to this cluster. There are a few higher energy clusters that have comparable energies, which likely means they have similar states. The cluster number could be optimized.

# %% [markdown]
# ### Monte Carlo

# %% [markdown]
# We attempt to incorporate a monte carlo version of the simulation, which allows for unfavorable energy moves with some probability proportional to the energy change relative to kBT.

# %% [markdown]
# We start with our simpler conformation:

# %%
shapes = {'shape 1': ['s', 10, 0, 0, {'patch 1': ['top right', 4, 0]}], 'shape 2':['s', 10, 6, 0, {'patch 1': ['top left', 4, 0], 'patch 2': ['bottom right', 4, 0]}], 'shape 3': ['s', 10, 6, 0, {'patch 1': ['bottom left', 4, 0],'patch 2': ['bottom right', 4, 0]}], 
          'shape 4': ['s', 10, 6, 0, {'patch 1': ['bottom left', 4, 0]}]}

hinge_vec, hinge_loc, shape_arr, linelist, patch_arr, patch_num = vis.generate(shapes)

vis.shapeplots(shape_arr, linelist, hinge_loc, blocking = False, title = 'Initial Sequence Conformation', show = True, bounds = '', mag_vecs = patch_arr)

# Define the magnetization/length of each patch. This is defined from experimental measured values as mentioned in the manuscript
m = np.array([1.01e-6]*sum(patch_num)) # Can change the values of the moments here if we do patches of different sizes

# Establish the magnetic vector containing all of the magnetizations/shape of each magnetic domain (ends of the patches), necessary for energy calculation
magvec = np.repeat(m, 2) # the endpoints are the domains we care about, so this is just a 2n-dim array of the same values as m, where n is the dim of m

mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat = vis.initialize_energy(magvec)

# %%
std = 10 # angle distribution std
max_iter = 1000 # maximum moves
patch_arr_sim, shape_arr_sim, hinge_vec_sim, hinge_loc_sim, current_energy_sim = sim.simulate_monteCarlo(patch_arr,shape_arr,linelist,hinge_vec, hinge_loc, std, patch_num, mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat, max_iter, kBT=4.11e-21)
vis.shapeplots(shape_arr_sim, linelist,hinge_loc_sim, mag_vecs = patch_arr_sim) # plot the resulting final state
print("Energy is: ", vis.energy_math(patch_arr_sim,mask_arr, v_xmat, h_xmat, v_ymat, h_ymat,Ml_mat))
# Out:
# Energy is:  -9.474473809737674e-11

# %%
# sim many times
std = 10 # angle distribution std
max_iter = 1000 # maximum moves
nsim = 100 # number of simulations
final_hinges, final_es = sim.sim_many(nsim, 'monte carlo',patch_arr,shape_arr,linelist,hinge_vec, hinge_loc, std, patch_num, mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat, max_iter, tol=0, plot=False)
# Out:
# Current energy:  -2.4096805371696135e-11  Joules
# Current energy:  -3.744767822627849e-11  Joules
# Current energy:  -1.1480411972704288e-11  Joules
# Current energy:  -8.50215093108515e-12  Joules
# Current energy:  -3.516573332062243e-11  Joules
# Current energy:  -3.371239381588968e-12  Joules
# Current energy:  -4.418250139360858e-11  Joules
# Current energy:  -2.1700488055469424e-11  Joules
# Current energy:  -5.527760129707486e-12  Joules
# Current energy:  -2.4000160429131676e-11  Joules
# Current energy:  -3.971148275914324e-12  Joules
# Current energy:  -1.709275051161521e-11  Joules
# Current energy:  -1.4127781001879916e-11  Joules
# Current energy:  -3.222261137218199e-11  Joules
# Current energy:  -1.9812148663659038e-11  Joules
# Current energy:  -1.0375804797686467e-11  Joules
# Current energy:  -1.3687768175710723e-11  Joules
# Current energy:  -4.305505658849581e-12  Joules
# Current energy:  -5.137652423047336e-12  Joules
# Current energy:  -3.299239903259745e-11  Joules
# Current energy:  -1.6900868280798853e-12  Joules
# Current energy:  -1.719063650899489e-11  Joules
# Current energy:  -2.6093804078452668e-11  Joules
# Current energy:  -9.966877796973394e-11  Joules
# Current energy:  -1.2091018859953197e-11  Joules
# Current energy:  -4.991729823394742e-11  Joules
# Current energy:  -7.58296699504276e-11  Joules
# Current energy:  -5.901959027263903e-12  Joules
# Current energy:  -5.739070233858926e-12  Joules
# Current energy:  -1.4355370104134398e-11  Joules
# Current energy:  -3.3677922709607955e-11  Joules
# Current energy:  -8.083244152294563e-12  Joules
# Current energy:  -4.934879631981707e-11  Joules
# Current energy:  -7.886249571704658e-12  Joules
# Current energy:  -1.8370598174489656e-11  Joules
# Current energy:  -5.754432204589097e-12  Joules
# Current energy:  -7.864070537957147e-12  Joules
# Current energy:  -6.292129454040071e-12  Joules
# Current energy:  -9.14281864503574e-12  Joules
# Current energy:  -5.628485965765693e-11  Joules
# Current energy:  -3.182149299967997e-11  Joules
# Current energy:  -8.156841928695267e-12  Joules
# Current energy:  -4.0398306889780556e-12  Joules
# Current energy:  -9.0552183405298e-12  Joules
# Current energy:  -1.7061987222139496e-11  Joules
# Current energy:  -9.00430442175797e-12  Joules
# Current energy:  -1.2122540548500493e-11  Joules
# Current energy:  -1.8020569571617694e-11  Joules
# Current energy:  -5.324128649777867e-12  Joules
# Current energy:  -1.0643713896420891e-11  Joules
# Current energy:  -3.511880643158429e-12  Joules
# Current energy:  -1.9938142739873313e-11  Joules
# Current energy:  -5.328847233973663e-11  Joules
# Current energy:  -4.158599141024447e-11  Joules
# Current energy:  -4.814991529451275e-12  Joules
# Current energy:  -3.037695411423207e-11  Joules
# Current energy:  -2.088426815416751e-11  Joules
# Current energy:  -4.1935581321334185e-12  Joules
# Current energy:  -2.0988455509956356e-11  Joules
# Current energy:  -4.048855363318585e-11  Joules
# Current energy:  -5.294942435904488e-12  Joules
# Current energy:  -6.029004215575926e-11  Joules
# Current energy:  -3.161983166620939e-11  Joules
# Current energy:  -4.7444788115828994e-11  Joules
# Current energy:  -2.78905615927438e-11  Joules
# Current energy:  -7.096710940001682e-12  Joules
# Current energy:  -1.1094303000333654e-11  Joules
# Current energy:  -6.412429285589328e-11  Joules
# Current energy:  -1.2934012218129007e-11  Joules
# Current energy:  -1.1852077485005755e-11  Joules
# Current energy:  -1.9857212053574207e-11  Joules
# Current energy:  -1.0495122637103514e-11  Joules
# Current energy:  -8.280850081696337e-12  Joules
# Current energy:  -1.2326186951581313e-11  Joules
# Current energy:  -6.029651879068825e-12  Joules
# Current energy:  -2.8192198802760886e-08  Joules
# Current energy:  -1.7991355983770686e-11  Joules
# Current energy:  -5.75051113990275e-12  Joules
# Current energy:  -2.045887314052268e-11  Joules
# Current energy:  -4.2971700580636465e-11  Joules
# Current energy:  -2.292757553959645e-11  Joules
# Current energy:  -1.2231444033735942e-11  Joules
# Current energy:  -2.4703829394890783e-11  Joules
# Current energy:  -1.283712407300144e-11  Joules
# Current energy:  -3.601008737302527e-10  Joules
# Current energy:  -8.701201266018934e-12  Joules
# Current energy:  -2.0083880475847817e-11  Joules
# Current energy:  -4.397512913398866e-11  Joules
# Current energy:  -2.8359686249645157e-10  Joules
# Current energy:  -3.927289943346191e-12  Joules
# Current energy:  -6.979381609260912e-12  Joules
# Current energy:  -7.855040875784962e-12  Joules
# Current energy:  -7.53533275457175e-12  Joules
# Current energy:  -6.927785467612505e-12  Joules
# Current energy:  -2.1253461399545214e-12  Joules
# Current energy:  -9.523862738621966e-12  Joules
# Current energy:  -5.697867593672753e-11  Joules
# Current energy:  -1.6545670730691185e-11  Joules
# Current energy:  -4.882613130460307e-11  Joules
# Current energy:  -5.706287354986536e-11  Joules

# %%
cluster_max = 5
states = 10 #A cluster parameter that allows the KMeans clustering to try out different initial states for better optimization
clusternumber = vis.cluster_num(final_hinges,cluster_max,states, Plot = False)
clustercenters, cluster_labels, clusternumber = vis.min_cluster_centers(final_hinges, clusternumber, final_es,Plots='3D')

# %%
clusternumbers, cluster_count, cluster_prob, energies, ordered_centers, all_stds = vis.cluster_stats(final_hinges, clusternumber, clustercenters, cluster_labels,
                                                                                                    final_es, plot=True)

# %% [markdown]
# So, the results are very similar to our previous method, suggesting that the conformation in this case is very deterministic. We now attempt the more complicated conformation.

# %%
shapes = {'shape 1': ['s', 10, 0, 0, {'patch 1': ['top right', 4, 0]}], 'shape 2':['s', 10, 6, 0, {'patch 1': ['top left', 4, 0], 'patch 2': ['bottom right', 4, 0]}], 'shape 3': ['s', 10, 6, 0, {'patch 1': ['bottom left', 4, 0]}], 
          'shape 4': ['s', 10, 6, 0, {'patch 1': ['bottom left', 4, 0]}], 'shape 5': ['s', 10, 6, 0, {'patch 1': ['top left', 4, 0]}], 'shape 6': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 7': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 8': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 9': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 10': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}], 'shape 11': ['s', 10, 6, 0, {'patch 1': ['bottom right', 4, 0]}]}

hinge_vec, hinge_loc, shape_arr, linelist, patch_arr, patch_num = vis.generate(shapes)

vis.shapeplots(shape_arr, linelist, hinge_loc, blocking = False, title = 'Initial Sequence Conformation', show = True, bounds = '', mag_vecs = patch_arr)

# Define the magnetization/length of each patch. This is defined from experimental measured values as mentioned in the manuscript
m = np.array([1.01e-6]*sum(patch_num)) # Can change the values of the moments here if we do patches of different sizes

# Establish the magnetic vector containing all of the magnetizations/shape of each magnetic domain (ends of the patches), necessary for energy calculation
magvec = np.repeat(m, 2) # the endpoints are the domains we care about, so this is just a 2n-dim array of the same values as m, where n is the dim of m

mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat = vis.initialize_energy(magvec)

# %%
std = 10 # angle distribution std
max_iter = 1000 # maximum moves
patch_arr_sim, shape_arr_sim, hinge_vec_sim, hinge_loc_sim, current_energy_sim = sim.simulate_monteCarlo(patch_arr,shape_arr,linelist,hinge_vec, hinge_loc, std, patch_num, mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat, max_iter, kBT=4.11e-21)
vis.shapeplots(shape_arr_sim, linelist,hinge_loc_sim, mag_vecs = patch_arr_sim) # plot the resulting final state

# %%
# sim many times
std = 10 # angle distribution std
max_iter = 1000 # maximum moves
nsim = 100 # number of simulations
final_hinges, final_es = sim.sim_many(nsim, 'monte carlo',patch_arr,shape_arr,linelist,hinge_vec, hinge_loc, std, patch_num, mask_arr, v_xmat, h_xmat, v_ymat, h_ymat, Ml_mat, max_iter, tol=0, plot=False)
# Out:
# Current energy:  -1.1443690230599213e-11  Joules
# Current energy:  -2.4978012720242916e-11  Joules
# Current energy:  -4.829894862115597e-11  Joules
# Current energy:  -1.0445566919883771e-11  Joules
# Current energy:  -2.2141565437895786e-11  Joules
# Current energy:  -1.6041474032716266e-10  Joules
# Current energy:  -3.640659232987074e-11  Joules
# Current energy:  -1.7605460705578424e-10  Joules
# Current energy:  -1.0878834882475802e-09  Joules
# Current energy:  -1.982566269280673e-11  Joules
# Current energy:  -2.623812769217875e-11  Joules
# Current energy:  -2.8422724204782364e-11  Joules
# Current energy:  -1.029384760944881e-11  Joules
# Current energy:  -3.0669818775824704e-11  Joules
# Current energy:  -8.709771156940432e-11  Joules
# Current energy:  -2.5960235482122317e-11  Joules
# Current energy:  -1.6896778228397308e-10  Joules
# Current energy:  -2.4380090102885417e-11  Joules
# Current energy:  -9.457940633684969e-11  Joules
# Current energy:  -1.0020460204691764e-11  Joules
# Current energy:  -6.125179146102949e-10  Joules
# Current energy:  -1.1495512793749098e-10  Joules
# Current energy:  -2.6952658443703947e-10  Joules
# Current energy:  -1.4569493839169845e-11  Joules
# Current energy:  -4.778846298454691e-11  Joules
# Current energy:  -2.153994089184933e-11  Joules
# Current energy:  -3.5028279430619935e-11  Joules
# Current energy:  -6.2419096988447016e-12  Joules
# Current energy:  -1.665559948992199e-11  Joules
# Current energy:  -2.7140580128344145e-10  Joules
# Current energy:  -3.167643558796627e-11  Joules
# Current energy:  -7.212678800403612e-11  Joules
# Current energy:  -2.4926121632781848e-11  Joules
# Current energy:  -9.49549238719774e-12  Joules
# Current energy:  -3.029204646655867e-11  Joules
# Current energy:  -6.32199867910582e-11  Joules
# Current energy:  -1.6882900538046093e-11  Joules
# Current energy:  -1.2455568560031316e-10  Joules
# Current energy:  -2.3790465395161365e-11  Joules
# Current energy:  -1.9161533591275446e-11  Joules
# Current energy:  -5.906592824732423e-12  Joules
# Current energy:  -6.014541731048991e-10  Joules
# Current energy:  -8.233806435213375e-11  Joules
# Current energy:  -1.8661433233560006e-10  Joules
# Current energy:  -3.8704208731807613e-10  Joules
# Current energy:  -2.337157893687594e-11  Joules
# Current energy:  -2.6066299492171356e-11  Joules
# Current energy:  -2.704576486565586e-11  Joules
# Current energy:  -1.0602329599246383e-11  Joules
# Current energy:  -4.940129013270318e-11  Joules
# Current energy:  -1.4388704940597093e-11  Joules
# Current energy:  -6.133167937568502e-11  Joules
# Current energy:  -1.1188451082178163e-11  Joules
# Current energy:  -1.5962637377683423e-10  Joules
# Current energy:  -1.0719918973483558e-10  Joules
# Current energy:  -4.55643919412882e-11  Joules
# Current energy:  -4.2853040152191613e-11  Joules
# Current energy:  -8.228126088652867e-11  Joules
# Current energy:  -2.4967069681252216e-10  Joules
# Current energy:  -2.5527948151719005e-11  Joules
# Current energy:  -9.175941757985026e-11  Joules
# Current energy:  -1.5818992732702505e-11  Joules
# Current energy:  -2.798715827731697e-11  Joules
# Current energy:  -3.2348732335335607e-10  Joules
# Current energy:  -1.36420820473385e-11  Joules
# Current energy:  -1.227772393807189e-10  Joules
# Current energy:  -1.4541159793671438e-11  Joules
# Current energy:  -3.615909861922797e-11  Joules
# Current energy:  -9.517451989797782e-11  Joules
# Current energy:  -7.574784771304031e-11  Joules
# Current energy:  -1.1067399748036813e-11  Joules
# Current energy:  -4.334887285442694e-11  Joules
# Current energy:  -2.2601524948910267e-10  Joules
# Current energy:  -4.705898028313823e-11  Joules
# Current energy:  -4.438564293055146e-11  Joules
# Current energy:  -1.475453245618308e-11  Joules
# Current energy:  -7.544317383282338e-11  Joules
# Current energy:  -6.455482815452452e-10  Joules
# Current energy:  -2.6408691323862842e-11  Joules
# Current energy:  -7.380877569384795e-11  Joules
# Current energy:  -3.4702810286532696e-11  Joules
# Current energy:  -4.150610450312781e-11  Joules
# Current energy:  -5.941792406757451e-11  Joules
# Current energy:  -1.2327784978094437e-11  Joules
# Current energy:  -8.994496979329173e-11  Joules
# Current energy:  -2.2841203140807103e-11  Joules
# Current energy:  -4.195607188049609e-11  Joules
# Current energy:  -2.9111060292837907e-11  Joules
# Current energy:  -4.318972655024897e-11  Joules
# Current energy:  -2.2119263933120999e-10  Joules
# Current energy:  -3.146465800873047e-11  Joules
# Current energy:  -1.2903558350298076e-10  Joules
# Current energy:  -7.983162619731268e-11  Joules
# Current energy:  -2.1914937070416954e-11  Joules
# Current energy:  -2.5260447021508306e-11  Joules
# Current energy:  -4.9081023448428016e-11  Joules
# Current energy:  -1.1597224194744583e-11  Joules
# Current energy:  -7.193272772814886e-11  Joules
# Current energy:  -3.191335079201555e-11  Joules
# Current energy:  -5.333781235095416e-11  Joules

# %%
cluster_max = 9
states = 10 #A cluster parameter that allows the KMeans clustering to try out different initial states for better optimization
clusternumber = vis.cluster_num(final_hinges,cluster_max,states, Plot = False)
clustercenters, cluster_labels, clusternumber = vis.min_cluster_centers(final_hinges, clusternumber, final_es)
clusternumbers, cluster_count, cluster_prob, energies, ordered_centers, all_stds = vis.cluster_stats(final_hinges, clusternumber, clustercenters, cluster_labels,
                                                                                                    final_es, plot=True)

# %% [markdown]
# We see that the Monte Carlo method stil yields a large proportion at lower energy with several clusters of various higher energy states. We observe a small very low energy population that is likely a result of Monte Carlo exploring more pathways than greedy descent. However, the general results (and the most likely conformations) appear roughly similar upon analysis, which points to a deterministic system.

# %% [markdown]
# ### Conclusions

# %% [markdown]
# We have seen two methods for simulating the folding of magnetic microrobots. The results for the deterministic greedy descent method were similar to the results for Monte Carlo, which indicates that our system is fairly deterministic. This result makes sense, as the energy scale of our system is many orders of magnitude larger than kBT, so unfavorable moves should hardly ever be accepted in the Monte Carlo process.
#
# In the future, I will look at more simulation methods and compare results of clustering. I aim to implement more physical methods than greedy descent to observe whether we see similar clusters. This analysis would reveal just how deterministic our system really is.
#
# However, we have made significant progess on this work through this project, and we now have a couple of methods to predict folding of our fabricated system. This informs our initial design, and allows for more practical applications in biomedical areas, such as drug delivery.
